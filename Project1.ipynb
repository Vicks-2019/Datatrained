# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\vikash\anaconda3\lib\site-packages (8.0.18)
# Collecting protobuf>=3.0.0 (from mysql-connector-python)
#   Downloading https://files.pythonhosted.org/packages/30/c6/286db43e2d0d4b89d328a222365c7a253a99a24067812253f0d4f8eb0f1c/protobuf-3.11.2-cp37-cp37m-win_amd64.whl (1.0MB)
# Requirement already satisfied: six>=1.9 in c:\users\vikash\appdata\roaming\python\python37\site-packages (from protobuf>=3.0.0->mysql-connector-python) (1.12.0)
# Requirement already satisfied: setuptools in c:\users\vikash\anaconda3\lib\site-packages (from protobuf>=3.0.0->mysql-connector-python) (41.4.0)
# Installing collected packages: protobuf
# Successfully installed protobuf-3.11.2

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host= "127.0.0.1",
    port= 3306,
    user="root",
    password="Helo@2019",
    database = "studmarks")

# %%
df = pd.read_sql_query("select * from students",con)
df
# Out:
#         Name  Gender   DOB  Physics  Chemistry  Biology  Economics  History  \
# 0       Name  Gender  None        0          0        0          0        0
# 1       John       M  None       55         45       56         87       21
# 2     Suresh       M  None       75         96       78         64       90
# 3     Ramesh       M  None       25         54       89         76       95
# 4    Jessica       F  None       78         96       86         63       54
# 5   Jennifer       F  None       58         96       78         46       96
# 6       Annu       F  None       45         87       52         89       55
# 7      pooja       F  None       55         64       61         58       75
# 8     Ritesh       M  None       54         76       87         56       25
# 9      Farha       F  None       55         63       89         75       78
# 10    Mukesh       M  None       96         46       77         83       58
# 11      Name  Gender  None        0          0        0          0        0
# 12      John       M  None       55         45       56         87       21
# 13    Suresh       M  None       75         96       78         64       90
# 14    Ramesh       M  None       25         54       89         76       95
# 15   Jessica       F  None       78         96       86         63       54
# 16  Jennifer       F  None       58         96       78         46       96
# 17      Annu       F  None       45         87       52         89       55
# 18     pooja       F  None       55         64       61         58       75
# 19    Ritesh       M  None       54         76       87         56       25
# 20     Farha       F  None       55         63       89         75       78
# 21    Mukesh       M  None       96         46       77         83       58
#
#     Civics
# 0        0
# 1       52
# 2       61
# 3       87
# 4       89
# 5       77
# 6       89
# 7       58
# 8       56
# 9       75
# 10      83
# 11       0
# 12      52
# 13      61
# 14      87
# 15      89
# 16      77
# 17      89
# 18      58
# 19      56
# 20      75
# 21      83

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
# Name         22 non-null object
# Gender       22 non-null object
# DOB          0 non-null object
# Physics      22 non-null int64
# Chemistry    22 non-null int64
# Biology      22 non-null int64
# Economics    22 non-null int64
# History      22 non-null int64
# Civics       22 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#          Physics  Chemistry    Biology  Economics    History     Civics
# count  22.000000  22.000000  22.000000  22.000000  22.000000  22.000000
# mean   54.181818  65.727273  68.454545  63.363636  58.818182  66.090909
# std    25.142710  28.609326  25.669562  24.488181  31.419794  25.318747
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    47.250000  48.000000  57.250000  56.500000  32.250000  56.500000
# 50%    55.000000  64.000000  78.000000  64.000000  58.000000  75.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Physics', 'Chemistry', 'Biology', 'Economics',
#        'History', 'Civics'],
#       dtype='object')

# %%
sns.heatmap(df.corr())
